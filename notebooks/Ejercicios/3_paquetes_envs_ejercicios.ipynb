# %% [markdown]
# # Ejercicios – Paquetes, archivos y arreglos (Sesión 3)
#
# Esta libreta contiene ejercicios para practicar el uso de paquetes, la carga de archivos y el manejo de arreglos con **NumPy**. Algunos ejercicios incluyen comandos de `pip` que se ejecutan anteponiendo un signo de exclamación `!` dentro de una celda de código.

# %% [markdown]
# ## 1. Paquetes y gestión de dependencias
#
# 1. Ejecuta `!pip list` para mostrar una lista de los paquetes instalados en tu entorno de Python.
# 2. Ejecuta `!pip show pandas` para ver la versión instalada de `pandas`.
# 3. Importa el módulo `math` y utiliza la función `math.sqrt()` para calcular la raíz cuadrada de 16.
# 4. Desde el módulo `random`, importa la función `choice` y úsala para seleccionar un color al azar de la lista `colores = ['rojo', 'verde', 'azul']`.
# 5. *(Opcional)* Escribe en una celda de Markdown los pasos básicos para crear un ambiente virtual con `python -m venv`.

# %%
# Tu código aquí

# %% [markdown]
# ## 2. Cargar archivos con pandas
#
# 1. Ejecuta la siguiente celda para crear un archivo CSV y uno Excel de ejemplo.
# 2. Usa `pd.read_csv()` para cargar el archivo `datos_ejemplo.csv` en un DataFrame.
# 3. Usa `pd.read_excel()` para cargar el archivo `datos_ejemplo.xlsx` en otro DataFrame.
# 4. Muestra las primeras filas de ambos DataFrames utilizando el método `.head()`.
# 5. Escribe código para mostrar únicamente las filas donde la edad es mayor a 30.
#
# **Consejo:** Importa `pandas` como `pd` al comienzo de la celda de código.

# %%
# 2. Cargar archivos con pandas
import pandas as pd

# Crea un DataFrame de ejemplo
df_ejemplo = pd.DataFrame({
    'Nombre': ['Ana', 'Luis', 'Pedro', 'María', 'Jorge'],
    'Edad': [23, 35, 19, 42, 31],
    'Ciudad': ['Ciudad de México', 'Guadalajara', 'Monterrey', 'Querétaro', 'Puebla']
})

# Guarda el DataFrame en archivos CSV y Excel
df_ejemplo.to_csv('datos_ejemplo.csv', index=False)
df_ejemplo.to_excel('datos_ejemplo.xlsx', index=False)

# Tu código para leer los archivos y filtrarlos va debajo de esta línea

# %%
# Tu código aquí

# %% [markdown]
# ## 3. Arreglos con NumPy
#
# 1. Importa `numpy` como `np` y crea un arreglo unidimensional con los números del 1 al 10. Calcula la suma y el promedio de sus elementos.
# 2. Crea dos arreglos `a` y `b` con valores `[1, 2, 3]` y `[4, 5, 6]` y realiza las operaciones de suma, resta y multiplicación elemento a elemento.
# 3. Genera un arreglo de 5 números aleatorios enteros entre 0 y 100 utilizando `np.random.randint`.
# 4. Crea un arreglo de fechas que inicie el 1 de enero de 2025 y contenga 10 días consecutivos usando `np.arange` con el tipo `datetime64`.

# %%
# Tu código aquí
