# %% [markdown]
# # Ejercicios – Introducción a Python (Sesión 1)
#
# En esta libreta encontrarás ejercicios para practicar los conceptos cubiertos en la **Sesión 1** del propedéutico de programación con Python. Lee cada instrucción y escribe tu código en las celdas de código correspondientes.

# %% [markdown]
# ## 1. Variables
#
# Crea variables de diferentes tipos (por ejemplo, cadena, entero, flotante y booleano). Debes asignar un nombre de usuario, su edad, su altura en metros y si está inscrito en el curso. Después imprime cada variable utilizando `print()`.

# %%
# Tu código aquí

# %% [markdown]
# ### 2.1 Operaciones aritméticas
#
# 1. Calcula el perímetro y el área de un rectángulo con base 5 y altura 3.
# 2. Calcula el valor de `10 ** 2`, `8 % 3` y `7 // 2`.

# %%
# Tu código aquí

# %% [markdown]
# ### 2.2 Operadores de asignación
#
# Crea una variable `contador` con valor `0`. Utiliza operadores de asignación (`+=`, `-=`, `*=` o `/=`) para actualizar su valor en al menos cuatro pasos distintos. Imprime el valor después de cada operación.

# %%
# Tu código aquí

# %% [markdown]
# ### 2.3 Operadores de comparación y lógicos
#
# 1. Escribe expresiones que comparen dos números (por ejemplo, `5 > 3`, `4 == 4`) y almacena los resultados en variables.
# 2. Usa operadores lógicos (`and`, `or`, `not`) para combinar comparaciones y determina si un número `x` está en el rango entre 10 y 20.
# 3. Imprime los resultados.

# %%
# Tu código aquí

# %% [markdown]
# ## 3. Comentarios
#
# Añade comentarios de una sola línea y de varias líneas a un bloque de código que calcule la suma de los números del 1 al 10. Explica qué hace cada parte del código en los comentarios.

# %%
# Tu código aquí

# %% [markdown]
# ## 4. Tipos de dato y conversiones
#
# 1. Declara una variable booleana que indique si tienes hambre.
# 2. Convierte el valor `3.14159` a entero y a cadena. Imprime ambos resultados.
# 3. Dada la cadena `'123'`, conviértela a entero y suma 7.
# 4. Verifica el tipo de cada variable utilizando la función `type()`.

# %%
# Tu código aquí

# %% [markdown]
# ### 4.1 Formateo de cadenas
#
# Utiliza f-strings o el método `.format()` para crear un mensaje que incluya tu nombre, tu edad y tu lugar de origen en una sola cadena. Por ejemplo: `"Hola, me llamo Ana, tengo 25 años y soy de Mérida."`.

# %%
# Tu código aquí

# %% [markdown]
# ## 5. Estructuras de datos
#
# ### 5.1 Listas
#
# 1. Crea una lista de al menos cinco números enteros.
# 2. Agrega un nuevo número al final y otro al inicio de la lista.
# 3. Elimina el tercer elemento de la lista.
# 4. Ordena la lista en orden ascendente.
# 5. Imprime la lista después de cada modificación.

# %%
# Tu código aquí

# %% [markdown]
# ### 5.2 Tuplas
#
# 1. Crea una tupla con tres nombres de tus amigos.
# 2. Intenta cambiar el segundo nombre (¿qué sucede?).
# 3. Convierte la tupla a una lista, agrega un nuevo nombre y vuelve a convertirla en una tupla.

# %%
# Tu código aquí

# %% [markdown]
# ### 5.3 Conjuntos (set)
#
# 1. Crea dos conjuntos: uno con tus tres lenguajes de programación favoritos y otro con tres lenguajes diferentes.
# 2. Encuentra la unión y la intersección de estos conjuntos.
# 3. Agrega un elemento a uno de los conjuntos y elimina otro.

# %%
# Tu código aquí

# %% [markdown]
# ### 5.4 Diccionarios
#
# 1. Crea un diccionario que represente la información de un estudiante con las claves `nombre`, `edad` y `promedio`.
# 2. Agrega una nueva clave `universidad`.
# 3. Actualiza el `promedio`.
# 4. Verifica si la clave `'edad'` existe en el diccionario utilizando el operador `in`.
# 5. Imprime el diccionario al final.

# %%
# Tu código aquí
